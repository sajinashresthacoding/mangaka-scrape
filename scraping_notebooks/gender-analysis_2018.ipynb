# %%
# !pip install icecream

# %%
## import necessary libraries
import pandas as pd
from icecream import ic 
import requests
from genderize import Genderize
import numpy as np

# %%
## bring in the complete dataset
df = pd.read_csv("all-gender-data_2018.csv")
df
# Out:
#                                                    book  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1374            A Certain Scientific Accelerator Vol. 8
# 1375                               Gantz Omnibus Vol. 2
# 1376                        High-Rise Invasion Vol. 5-6
# 1377  Hungry for You: Endo Yasuko Stalks the Night V...
# 1378              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                           Mitsu Izumi
# 1                                         Yuji Terajima
# 2                                        Ryoko Fukuyama
# 3                                     Yukihiro Kajimoto
# ...

# %%
##writing a function that will immediately give me the flags for pct
def pct_flag(number, pct):
    if number < pct:
        return "flag"
    else:
        return "pass"

# %%
df['gender_prob'] = df.apply(lambda x: pct_flag(x["gender_prob"], 0.95), axis = 1)
df
# Out:
#                                                    book  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1374            A Certain Scientific Accelerator Vol. 8
# 1375                               Gantz Omnibus Vol. 2
# 1376                        High-Rise Invasion Vol. 5-6
# 1377  Hungry for You: Endo Yasuko Stalks the Night V...
# 1378              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                           Mitsu Izumi
# 1                                         Yuji Terajima
# 2                                        Ryoko Fukuyama
# 3                                     Yukihiro Kajimoto
# ...

# %%
##writing a function that will immediately give me the flags for count
def count_flag(number, count):
    if number < count:
        return "flag"
    else:
        return(number)

# %%
df['gender_count_pf'] = df.apply(lambda x: pct_flag(x["gender_count"], 1_000), axis = 1)
df
# Out:
#                                                    book  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1374            A Certain Scientific Accelerator Vol. 8
# 1375                               Gantz Omnibus Vol. 2
# 1376                        High-Rise Invasion Vol. 5-6
# 1377  Hungry for You: Endo Yasuko Stalks the Night V...
# 1378              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                           Mitsu Izumi
# 1                                         Yuji Terajima
# 2                                        Ryoko Fukuyama
# 3                                     Yukihiro Kajimoto
# ...

# %%
df.to_csv('ready-to-check_2018.csv')
