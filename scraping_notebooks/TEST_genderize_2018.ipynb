# %%
# !pip install Genderize
# Out:
# Requirement already satisfied: Genderize in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: requests>=1.0.0 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from Genderize) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from requests>=1.0.0->Genderize) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from requests>=1.0.0->Genderize) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from requests>=1.0.0->Genderize) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from requests>=1.0.0->Genderize) (2022.9.24)

# %%
# !pip install icecream
# Out:
# Requirement already satisfied: icecream in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (2.1.3)
# Requirement already satisfied: colorama>=0.3.9 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from icecream) (0.4.5)
# Requirement already satisfied: pygments>=2.2.0 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from icecream) (2.11.2)
# Requirement already satisfied: asttokens>=2.0.1 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from icecream) (2.4.0)
# Requirement already satisfied: executing>=0.3.1 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from icecream) (2.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (from asttokens>=2.0.1->icecream) (1.16.0)

# %%
## import necessary libraries
import pandas as pd
from genderize import Genderize as gd
from icecream import ic

# %%
## read csv file into pandas dataframe
## see the head
df = pd.read_csv("test2_all2018_scrape.csv")
df
# Out:
#                                                    name  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1379            A Certain Scientific Accelerator Vol. 8
# 1380                               Gantz Omnibus Vol. 2
# 1381                        High-Rise Invasion Vol. 5-6
# 1382  Hungry for You: Endo Yasuko Stalks the Night V...
# 1383              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                        By Mitsu Izumi
# 1                                      By Yuji Terajima
# 2                                     By Ryoko Fukuyama
# 3                                  By Yukihiro Kajimoto
# 4                                         By Kazue Kato
# ...                                                 ...
# 1379  By Kazuma Kamachi (Author), Arata Yamaji (Illu...
# 1380  By Hiroya Oku (Author), Richard Pini (Illustra...
# 1381  By Tsuina Miura (Author), Takahiro Oba (Illust...
# 1382                            By Flowerchild (Author)
# 1383   By Mitsuki Mihara (Author), MonRin (Illustrator)
#
#                        company           medium     month
# 0                    Viz Media            Manga   january
# 1                     Kodansha  Digital Edition   january
# 2                    Viz Media            Manga   january
# 3                     Kodansha  Digital Edition   january
# 4                    Viz Media            Manga   january
# ...                        ...              ...       ...
# 1379  Seven Seas Entertainment            Manga  december
# 1380                Dark Horse            Manga  december
# 1381  Seven Seas Entertainment            Manga  december
# 1382  Seven Seas Entertainment            Manga  december
# 1383  Seven Seas Entertainment            Manga  december
#
# [1384 rows x 5 columns]

# %%
##i spot checked the data, all of it looks clean

# %%
##cleaning up dataframe
##1. deleteing "by" from every row of mangaka
df["mangaka"] = df["mangaka"].str.replace("By " , "")
df
# Out:
#                                                    name  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1379            A Certain Scientific Accelerator Vol. 8
# 1380                               Gantz Omnibus Vol. 2
# 1381                        High-Rise Invasion Vol. 5-6
# 1382  Hungry for You: Endo Yasuko Stalks the Night V...
# 1383              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                           Mitsu Izumi
# 1                                         Yuji Terajima
# 2                                        Ryoko Fukuyama
# 3                                     Yukihiro Kajimoto
# 4                                            Kazue Kato
# ...                                                 ...
# 1379  Kazuma Kamachi (Author), Arata Yamaji (Illustr...
# 1380    Hiroya Oku (Author), Richard Pini (Illustrator)
# 1381  Tsuina Miura (Author), Takahiro Oba (Illustrator)
# 1382                               Flowerchild (Author)
# 1383      Mitsuki Mihara (Author), MonRin (Illustrator)
#
#                        company           medium     month
# 0                    Viz Media            Manga   january
# 1                     Kodansha  Digital Edition   january
# 2                    Viz Media            Manga   january
# 3                     Kodansha  Digital Edition   january
# 4                    Viz Media            Manga   january
# ...                        ...              ...       ...
# 1379  Seven Seas Entertainment            Manga  december
# 1380                Dark Horse            Manga  december
# 1381  Seven Seas Entertainment            Manga  december
# 1382  Seven Seas Entertainment            Manga  december
# 1383  Seven Seas Entertainment            Manga  december
#
# [1384 rows x 5 columns]

# %%
##2. seperating author from mangaka
##couldnt figure that out so i just seperated in by author first name, i only need that anyways
df['author_firstname'] = df['mangaka'].str.split(' ').str[0]
df
# Out:
#                                                    name  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1379            A Certain Scientific Accelerator Vol. 8
# 1380                               Gantz Omnibus Vol. 2
# 1381                        High-Rise Invasion Vol. 5-6
# 1382  Hungry for You: Endo Yasuko Stalks the Night V...
# 1383              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                           Mitsu Izumi
# 1                                         Yuji Terajima
# 2                                        Ryoko Fukuyama
# 3                                     Yukihiro Kajimoto
# 4                                            Kazue Kato
# ...                                                 ...
# 1379  Kazuma Kamachi (Author), Arata Yamaji (Illustr...
# 1380    Hiroya Oku (Author), Richard Pini (Illustrator)
# 1381  Tsuina Miura (Author), Takahiro Oba (Illustrator)
# 1382                               Flowerchild (Author)
# 1383      Mitsuki Mihara (Author), MonRin (Illustrator)
#
#                        company           medium     month author_firstname
# 0                    Viz Media            Manga   january            Mitsu
# 1                     Kodansha  Digital Edition   january             Yuji
# 2                    Viz Media            Manga   january            Ryoko
# 3                     Kodansha  Digital Edition   january         Yukihiro
# 4                    Viz Media            Manga   january            Kazue
# ...                        ...              ...       ...              ...
# 1379  Seven Seas Entertainment            Manga  december           Kazuma
# 1380                Dark Horse            Manga  december           Hiroya
# 1381  Seven Seas Entertainment            Manga  december           Tsuina
# 1382  Seven Seas Entertainment            Manga  december      Flowerchild
# 1383  Seven Seas Entertainment            Manga  december          Mitsuki
#
# [1384 rows x 6 columns]

# %%
## renaming a column cuase it would get confusing 
df.rename(columns = {'name':'book'}, inplace = True)
df
# Out:
#                                                    book  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1379            A Certain Scientific Accelerator Vol. 8
# 1380                               Gantz Omnibus Vol. 2
# 1381                        High-Rise Invasion Vol. 5-6
# 1382  Hungry for You: Endo Yasuko Stalks the Night V...
# 1383              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka  \
# 0                                           Mitsu Izumi
# 1                                         Yuji Terajima
# 2                                        Ryoko Fukuyama
# 3                                     Yukihiro Kajimoto
# 4                                            Kazue Kato
# ...                                                 ...
# 1379  Kazuma Kamachi (Author), Arata Yamaji (Illustr...
# 1380    Hiroya Oku (Author), Richard Pini (Illustrator)
# 1381  Tsuina Miura (Author), Takahiro Oba (Illustrator)
# 1382                               Flowerchild (Author)
# 1383      Mitsuki Mihara (Author), MonRin (Illustrator)
#
#                        company           medium     month author_firstname
# 0                    Viz Media            Manga   january            Mitsu
# 1                     Kodansha  Digital Edition   january             Yuji
# 2                    Viz Media            Manga   january            Ryoko
# 3                     Kodansha  Digital Edition   january         Yukihiro
# 4                    Viz Media            Manga   january            Kazue
# ...                        ...              ...       ...              ...
# 1379  Seven Seas Entertainment            Manga  december           Kazuma
# 1380                Dark Horse            Manga  december           Hiroya
# 1381  Seven Seas Entertainment            Manga  december           Tsuina
# 1382  Seven Seas Entertainment            Manga  december      Flowerchild
# 1383  Seven Seas Entertainment            Manga  december          Mitsuki
#
# [1384 rows x 6 columns]

# %%
##re-ordering columns
df = df[['book', 'mangaka', 'author_firstname', 'company', 'medium', 'month']].copy()
df
# Out:
#                                                    book  \
# 0                                      7thGARDEN Vol. 7
# 1       Ace of the Diamond Vol. 7 [Kindle & comiXology]
# 2                                Anonymous Noise Vol. 6
# 3                 Ayanashi Vol. 2 [Kindle & comiXology]
# 4                                 Blue Exorcist Vol. 18
# ...                                                 ...
# 1379            A Certain Scientific Accelerator Vol. 8
# 1380                               Gantz Omnibus Vol. 2
# 1381                        High-Rise Invasion Vol. 5-6
# 1382  Hungry for You: Endo Yasuko Stalks the Night V...
# 1383              Magika Swordsman and Summoner Vol. 10
#
#                                                 mangaka author_firstname  \
# 0                                           Mitsu Izumi            Mitsu
# 1                                         Yuji Terajima             Yuji
# 2                                        Ryoko Fukuyama            Ryoko
# 3                                     Yukihiro Kajimoto         Yukihiro
# 4                                            Kazue Kato            Kazue
# ...                                                 ...              ...
# 1379  Kazuma Kamachi (Author), Arata Yamaji (Illustr...           Kazuma
# 1380    Hiroya Oku (Author), Richard Pini (Illustrator)           Hiroya
# 1381  Tsuina Miura (Author), Takahiro Oba (Illustrator)           Tsuina
# 1382                               Flowerchild (Author)      Flowerchild
# 1383      Mitsuki Mihara (Author), MonRin (Illustrator)          Mitsuki
#
#                        company           medium     month
# 0                    Viz Media            Manga   january
# 1                     Kodansha  Digital Edition   january
# 2                    Viz Media            Manga   january
# 3                     Kodansha  Digital Edition   january
# 4                    Viz Media            Manga   january
# ...                        ...              ...       ...
# 1379  Seven Seas Entertainment            Manga  december
# 1380                Dark Horse            Manga  december
# 1381  Seven Seas Entertainment            Manga  december
# 1382  Seven Seas Entertainment            Manga  december
# 1383  Seven Seas Entertainment            Manga  december
#
# [1384 rows x 6 columns]

# %%
##using genderize now
## FUNCTION to get gender data from genderize
def gender_data(name):
    '''
    takes a string name and returns gender data
    '''
    converted_to_list = [name]
    gender_data = gd().get(converted_to_list)
    return gender_data

# %%
def gender_estimate(name):
    '''
    takes a string name, returns gender based on using gender_data function
    '''
    return gender_data(name)[0].get("gender")

# %%
def gender_prob(name):
    '''
    takes a string name, returns gender probability based on using gender_data function
    '''
    return gender_data(name)[0].get("probability")

# %%
def gender_certainty(name, min_prob):
    '''
    takes a string name and the min_prob, returns gender probability based on using gender_data function
    '''
    prob = gender_data(name)[0].get("probability")
    if prob >= min_prob:
        return "pass"
    else:
        return "flag"

# %%
##let's make the occurence

def gender_count(name, appearance):
    '''
    takes a string name and the min_prob, returns gender probability based on using gender_data function
    '''
    count = gender_data(name)[0].get("count")
    if count >= appearance:
        return "sufficient"
    else:
        return "recheck"

# %%
df["gender"] = df["author_firstname"].apply(lambda x: gender_estimate(x))
df
# Out:
# ---------------------------------------------------------------------------
# GenderizeException                        Traceback (most recent call last)
# /var/folders/s2/yhgvwy5j2nj1j2xfcsx5gwp00000gn/T/ipykernel_14824/802550373.py in <module>
# ----> 1 df["gender"] = df["author_firstname"].apply(lambda x: gender_estimate(x))
#       2 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/s2/yhgvwy5j2nj1j2xfcsx5gwp00000gn/T/ipykernel_14824/802550373.py in <lambda>(x)
# ----> 1 df["gender"] = df["author_firstname"].apply(lambda x: gender_estimate(x))
#       2 df
#
# /var/folders/s2/yhgvwy5j2nj1j2xfcsx5gwp00000gn/T/ipykernel_14824/752891465.py in gender_estimate(name)
#       3     takes a string name, returns gender based on using gender_data function
#       4     '''
# ----> 5     return gender_data(name)[0].get("gender")
#
# /var/folders/s2/yhgvwy5j2nj1j2xfcsx5gwp00000gn/T/ipykernel_14824/4107632114.py in gender_data(name)
#       6     '''
#       7     converted_to_list = [name]
# ----> 8     gender_data = gd().get(converted_to_list)
#       9     return gender_data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/genderize/__init__.py in get(self, names, country_id, language_id, retheader)
#      94         :raises GenderizeException: if API server returns HTTP error code.
#      95         """
# ---> 96         responses = [
#      97             self._get_chunk(name_chunk, country_id, language_id)
#      98             for name_chunk
#
# ~/opt/anaconda3/lib/python3.9/site-packages/genderize/__init__.py in <listcomp>(.0)
#      95         """
#      96         responses = [
# ---> 97             self._get_chunk(name_chunk, country_id, language_id)
#      98             for name_chunk
#      99             in _chunked(names, Genderize.BATCH_SIZE)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/genderize/__init__.py in _get_chunk(self, name_chunk, country_id, language_id)
#     147             return _GenderizeResponse(data=decoded, headers=response.headers)
#     148         else:
# --> 149             raise GenderizeException(
#     150                 decoded['error'],
#     151                 response.status_code,
#
# GenderizeException: ('Request limit reached', 429, {'Server': 'nginx/1.16.1', 'Date': 'Fri, 24 Nov 2023 15:53:24 GMT', 'Content-Type': 'application/json', 'Content-Length': '33', 'Connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'x-rate-limit-limit,x-rate-limit-remaining,x-rate-limit-reset', 'cache-control': 'max-age=0, private, must-revalidate', 'x-rate-limit-limit': '1000', 'x-rate-limit-remaining': '0', 'x-rate-limit-reset': '29196', 'x-request-id': 'F5qaEGQ-_ig5IKABVrHC'})
